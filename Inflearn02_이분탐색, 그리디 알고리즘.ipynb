# %% [markdown]
# ## 이분 검색

# %% [markdown]
# - (중요!)먼저 정렬을 해놔야한다!
# - 맨 왼쪽 인덱스 가르키는 변수(lt)와 맨 오른쪽을 인덱스 가르키는 변수(rt)
# - lt ~ rt 검색하고자하는 데이터의 범위
# - mid라는 중간 변수를 지정 (mid=lt+rt // 2)
# 1. mid가 찾고자하는 숫자인지 확인
# 2. 아니면 큰지 작은지 비교한 뒤 그 방향으로 찾으러 감
# 3. 검색할때마다 답이 아닌 절반을 날리면서 찾는다. (그래서 logN번만에 찾을 수 있따)

# %%
n,m=map(int,input().split())
l=list(map(int,input().split()))
l.sort()

lt=0
rt=n-1

while lt<=rt:
    mid=(lt+rt)//2
    if l[mid]==m:
        print(mid+1)
        break
    elif l[mid]>m:
        rt=mid-1
    else: lt=mid+1
# Out:
# 3

# %% [markdown]
# ## 랜선자르기(결정알고리즘)

# %%
k,n=map(int,input().split())

for _ in range(k):
    a=int(input())



print()
# Out:
# 229

# %% [markdown]
# ## 뮤직비디오(결정알고리즘)

# %% [markdown]
# ## 뮤직비디오 반례 수정 영상

# %% [markdown]
# ## 마구간 정하기(결정아고리즘)

# %% [markdown]
# ## 화의실 배정(그리디)

# %% [markdown]
# ## 씨름 선수(그리디)

# %% [markdown]
# ## 창고 정리(그리디)

# %% [markdown]
# ## 침몰하는 타이타닉(그리디)

# %% [markdown]
# ## 증가 수열 만들기(그리디)

# %% [markdown]
# ## 역수열(그리디)
